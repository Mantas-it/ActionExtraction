# %%
##### FOR USPTO APPLICATIONS, starting with 1976

# %%
import xml.etree.ElementTree as ET
import pandas as pd
from glob import glob
import zipfile
import os
import html
import re

# %%
#Designate the years to extract. All files must be zipped (default) and in separate folders with the year as the name.
year_list = ['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']

# %%
# The location of the folders
disk_location = 'F:/US_applications/'

# %%
listoffiles_all = []

# %%
test = False
#test = False
if test == False:
    for y in year_list:
        listoffiles_temp = glob(disk_location+'%s/*.zip'%y)
        listoffiles_all.append(listoffiles_temp)
if test != False:
    listoffiles_all = [glob(disk_location+'%s/*.zip'%test)]

listoffiles_all

# %%
for year_now_idx,listoffiles in enumerate(listoffiles_all):
    for file_number,onezipfile in enumerate(listoffiles):
        print(onezipfile)
        PAT = []
        PAT_T = []
        YEAR = []
        Parag = []
        
        
        year_now = int(year_list[year_now_idx])
        if test != False:
            year_now = test
        
        zip = zipfile.ZipFile(onezipfile)
        zip.extractall(disk_location + '%s/'%year_now)
        zip.close()
        try:
            with open(disk_location + '%s/'%year_now+onezipfile[23:-4]+'.xml', 'r+') as fp:
                lines = fp.readlines()
        except:
            with open(disk_location + '%s/PGPUBprod/'%year_now+onezipfile[23:-4]+'.xml', 'r+') as fp:
                lines = fp.readlines()
        all_patent = []
        patent_id = 0
        current_pat_temp = ''
        p=0
        while p < len(lines):
            #if p%100000==0:
                #print(p)
            if lines[p] == '<?xml version="1.0" encoding="UTF-8"?>\n':
                if p != 0:
                    patent_id +=1
                    all_patent.append(current_pat_temp)
                    current_pat_temp = lines[p]
                    p+=1
                    continue
            current_pat_temp += lines[p]
            p+=1  
        try:
            os.remove(disk_location + '%s/'%year_now+onezipfile[23:-4]+'.xml')    
        except:
            os.remove(disk_location + '%s/PGPUBprod/'%year_now+onezipfile[23:-4]+'.xml')    


        count = 0
        for num_pat,one_patent in enumerate(all_patent):
            #print(num_pat)
            
            if year_now >2005:
                one_patent = re.sub(r'<figref idref="DRAWINGS">[A-Za-z0-9.\s@]*</figref>',"",one_patent)

                one_patent = one_patent.replace('<i>','')
                one_patent = one_patent.replace('</i>','')
                one_patent = one_patent.replace('<b>','')
                one_patent = one_patent.replace('</b>','')
                one_patent = one_patent.replace('<sup>','')
                one_patent = one_patent.replace('</sup>','')
                one_patent = one_patent.replace('<sub>','')
                one_patent = one_patent.replace('</sub>','')
                try:
                    tree = ET.fromstring(one_patent)
                except:
                    print('error on: ',num_pat)
                    continue
            if year_now == 2005:
                one_patent = one_patent.replace('&#x3c;','')
                one_patent=html.unescape(one_patent)
                one_patent = re.sub(r'<figref idref="DRAWINGS">[A-Za-z0-9.\s@]*</figref>',"",one_patent)
                one_patent = one_patent.replace('<i>','')
                one_patent = one_patent.replace('</i>','')
                one_patent = one_patent.replace('<b>','')
                one_patent = one_patent.replace('</b>','')
                one_patent = one_patent.replace('<sup>','')
                one_patent = one_patent.replace('</sup>','')
                one_patent = one_patent.replace('<sub>','')
                one_patent = one_patent.replace('</sub>','')
                one_patent = one_patent.replace('&','')
                #one_patent = re.sub(r"\s>\s","",one_patent)
                #one_patent = re.sub(r"\s<\s","",one_patent)
                #one_patent = re.sub(r"<[0-9]+","",one_patent)
                #one_patent = re.sub(r"[A-Z]<[A-Z]","",one_patent)
                #one_patent = re.sub(r"[0-9]<[A-Z]","",one_patent)
                #one_patent = re.sub(r"[0-9]<[a-z]","",one_patent)
                #one_patent = one_patent.replace('<<<','<')
                #one_patent = one_patent.replace('>>>','>')
                #one_patent = one_patent.replace('<<','<')
                #one_patent = one_patent.replace('>>','>')
                #one_patent = one_patent.replace('<|','')
                #one_patent = one_patent.replace('<(','')
                #one_patent = one_patent.replace('<{','')
                #print(num_pat)
                try:
                    tree = ET.fromstring(one_patent)
                except:
                    print('error on: ',num_pat)
                    continue
            if 2001 <= year_now <= 2004:
                one_patent_mod=html.unescape(one_patent)
                
                one_patent_mod = one_patent_mod.replace('&agr;','α')
                one_patent_mod = one_patent_mod.replace('&bgr;','β')
                one_patent_mod = one_patent_mod.replace('&Dgr;','Δ')
                one_patent_mod = one_patent_mod.replace('&ggr;','γ')
                one_patent_mod = one_patent_mod.replace('&dgr;','δ')
                one_patent_mod = one_patent_mod.replace('&Ggr;','Γ')
                one_patent_mod = one_patent_mod.replace('&ggr;','γ')
                one_patent_mod = one_patent_mod.replace('&mgr;','μ')
                one_patent_mod = one_patent_mod.replace('&phgr;','φ')
                one_patent_mod = one_patent_mod.replace('&PHgr;','Φ')
                one_patent_mod = one_patent_mod.replace('&thgr;','θ')
                one_patent_mod = one_patent_mod.replace('&THgr;','Θ')
                one_patent_mod = one_patent_mod.replace('&Lgr;','Λ')
                one_patent_mod = one_patent_mod.replace('&lgr;','λ')
                one_patent_mod = one_patent_mod.replace('&Sgr;','Σ')
                one_patent_mod = one_patent_mod.replace('&sgr;','σ')
                one_patent_mod = one_patent_mod.replace('&OHgr;','Ω')
                one_patent_mod = one_patent_mod.replace('&ohgr;','ω')
                one_patent_mod = one_patent_mod.replace('&Ngr;','Ν')
                one_patent_mod = one_patent_mod.replace('&ngr;','ν')
                one_patent_mod = one_patent_mod.replace('&Pgr;','Π')
                one_patent_mod = one_patent_mod.replace('&pgr;','π')
                one_patent_mod = one_patent_mod.replace('&ugr;','υ')
                one_patent_mod = one_patent_mod.replace('&Ugr;','Υ')
                one_patent_mod = one_patent_mod.replace('&egr;','ε')
                one_patent_mod = one_patent_mod.replace('&Egr;','Ε')
                one_patent_mod = one_patent_mod.replace('&EEgr;','Η')
                one_patent_mod = one_patent_mod.replace('&eegr;','η')
                one_patent_mod = one_patent_mod.replace('&Rgr;','Ρ')
                one_patent_mod = one_patent_mod.replace('&rgr;','ρ')
                one_patent_mod = one_patent_mod.replace('&KHgr;','Χ')
                one_patent_mod = one_patent_mod.replace('&khgr;','χ')
                one_patent_mod = one_patent_mod.replace('&Igr;','Ι')
                one_patent_mod = one_patent_mod.replace('&igr;','ι')
                one_patent_mod = one_patent_mod.replace('&Tgr;','Τ')
                one_patent_mod = one_patent_mod.replace('&tgr;','τ')
                one_patent_mod = one_patent_mod.replace('&Kgr;','Κ')
                one_patent_mod = one_patent_mod.replace('&kgr;','κ')
                one_patent_mod = one_patent_mod.replace('&Zgr;','Ζ')
                one_patent_mod = one_patent_mod.replace('&zgr;','ζ')
                one_patent_mod = one_patent_mod.replace('&Xgr;','Ξ')
                one_patent_mod = one_patent_mod.replace('&xgr;','ξ')
                one_patent_mod = one_patent_mod.replace('&psgr;','Ψ')
                one_patent_mod = one_patent_mod.replace('&PSgr;','ψ')
                one_patent_mod = one_patent_mod.replace('&Ogr;','Ο')
                one_patent_mod = one_patent_mod.replace('&ogr;','ο')
                one_patent_mod = one_patent_mod.replace('&Asteriskpseud;','')
                one_patent_mod = one_patent_mod.replace('&Brketclosest;','')
                one_patent_mod = one_patent_mod.replace('&Brketopenst;','')
                one_patent_mod = one_patent_mod.replace('&RightDoubleBracketingBar;','')
                one_patent_mod = one_patent_mod.replace('&LeftDoubleBracketingBar;','')
                one_patent_mod = one_patent_mod.replace('&AutoRightMatch;','')
                one_patent_mod = one_patent_mod.replace('&AutoLeftMatch;','')
                one_patent_mod = one_patent_mod.replace('&LeftBracketingBar;','⌈')
                one_patent_mod = one_patent_mod.replace('&RightBracketingBar;','⌉')
                one_patent_mod = one_patent_mod.replace('FD&C','')
                one_patent_mod = one_patent_mod.replace('&Parenopenst;','(')
                one_patent_mod = one_patent_mod.replace('&Parenclosest;','(')
                one_patent_mod = one_patent_mod.replace('<<<','<')
                one_patent_mod = one_patent_mod.replace('>>>','>')
                one_patent_mod = one_patent_mod.replace('<<','<')
                one_patent_mod = one_patent_mod.replace('>>','>')
                one_patent_mod = one_patent_mod.replace('<highlight>','')
                one_patent_mod = one_patent_mod.replace('</highlight>','')
                one_patent_mod = one_patent_mod.replace('<bold>','')
                one_patent_mod = one_patent_mod.replace('</bold>','')
                one_patent_mod = one_patent_mod.replace('<italic>','')
                one_patent_mod = one_patent_mod.replace('</italic>','')
                one_patent_mod = one_patent_mod.replace('<superscript>1</superscript>','')
                one_patent_mod = one_patent_mod.replace('<superscript>1 </superscript>','')
                one_patent_mod = one_patent_mod.replace('<superscript> 1</superscript>','')
                one_patent_mod = one_patent_mod.replace('<subscript>','')
                one_patent_mod = one_patent_mod.replace('</subscript>','')
                one_patent_mod = one_patent_mod.replace('<superscript>','')
                one_patent_mod = one_patent_mod.replace('</superscript>','')
                one_patent_mod = one_patent_mod.replace('<uline>','')
                one_patent_mod = one_patent_mod.replace('</uline>','')
                one_patent_mod = re.sub(r'[A-Z]&',"",one_patent_mod)
                one_patent_mod = re.sub(r'[0-9]&',"",one_patent_mod)
                one_patent_mod = re.sub(r'[a-zA-Z]&[a-zA-Z]',"",one_patent_mod)
                one_patent_mod = one_patent_mod.replace('& ','and ')
                one_patent_mod = one_patent_mod.replace(' &',' and')
                one_patent_mod = one_patent_mod.replace('“&”','')
                one_patent_mod = one_patent_mod.replace("′&",'')
                one_patent_mod = one_patent_mod.replace(",&",'')
                one_patent_mod = one_patent_mod.replace("(&)",'')
                one_patent_mod = one_patent_mod.replace(")&(",'')
                one_patent_mod = one_patent_mod.replace("&&",'')
                one_patent_mod = re.sub(r"\s>\s","",one_patent_mod)
                one_patent_mod = re.sub(r"\s<\s","",one_patent_mod)
                one_patent_mod = re.sub(r"<[0-9]+","",one_patent_mod)
                #one_patent_mod = re.sub(r"[0-9]+>[0-9]+","",one_patent_mod)
                #one_patent_mod = re.sub(r"<number>\[[0-9]+\]</number>","",one_patent_mod)
                one_patent_mod = re.sub(r"<number>\[[0-9]+\]</number>","",one_patent_mod)
                one_patent_mod = re.sub(r"<number>[0-9]+\.</number>","",one_patent_mod)
                one_patent_mod = re.sub(r'<cross-reference target="DRAWINGS">[A-Za-z0-9.\s@]*</cross-reference>',"",one_patent_mod)

                
                   #print(desc)html.unescape('&pound;682m')
               
                try:
                    tree = ET.fromstring(one_patent_mod)
                except:
                    one_patent_mod = one_patent.replace('&lt;','')
                    one_patent_mod = one_patent_mod.replace('&rt;','')
                    
                    one_patent_mod=html.unescape(one_patent_mod)
                    one_patent_mod = one_patent_mod.replace('&agr;','α')
                    one_patent_mod = one_patent_mod.replace('&bgr;','β')
                    one_patent_mod = one_patent_mod.replace('&Dgr;','Δ')
                    one_patent_mod = one_patent_mod.replace('&ggr;','γ')
                    one_patent_mod = one_patent_mod.replace('P&G','')
                    one_patent_mod = one_patent_mod.replace('&dgr;','δ')
                    one_patent_mod = one_patent_mod.replace('&Ggr;','Γ')
                    one_patent_mod = one_patent_mod.replace('&ggr;','γ')
                    one_patent_mod = one_patent_mod.replace('&mgr;','μ')
                    one_patent_mod = one_patent_mod.replace('&phgr;','φ')
                    one_patent_mod = one_patent_mod.replace('&PHgr;','Φ')
                    one_patent_mod = one_patent_mod.replace('&thgr;','θ')
                    one_patent_mod = one_patent_mod.replace('&THgr;','Θ')
                    one_patent_mod = one_patent_mod.replace('&Lgr;','Λ')
                    one_patent_mod = one_patent_mod.replace('&lgr;','λ')
                    one_patent_mod = one_patent_mod.replace('&Sgr;','Σ')
                    one_patent_mod = one_patent_mod.replace('&sgr;','σ')
                    one_patent_mod = one_patent_mod.replace('&OHgr;','Ω')
                    one_patent_mod = one_patent_mod.replace('&ohgr;','ω')
                    one_patent_mod = one_patent_mod.replace('&Ngr;','Ν')
                    one_patent_mod = one_patent_mod.replace('&ngr;','ν')
                    one_patent_mod = one_patent_mod.replace('&Pgr;','Π')
                    one_patent_mod = one_patent_mod.replace('&pgr;','π')
                    one_patent_mod = one_patent_mod.replace('&ugr;','υ')
                    one_patent_mod = one_patent_mod.replace('&Ugr;','Υ')
                    one_patent_mod = one_patent_mod.replace('&egr;','ε')
                    one_patent_mod = one_patent_mod.replace('&Egr;','Ε')
                    one_patent_mod = one_patent_mod.replace('&EEgr;','Η')
                    one_patent_mod = one_patent_mod.replace('&eegr;','η')
                    one_patent_mod = one_patent_mod.replace('&Rgr;','Ρ')
                    one_patent_mod = one_patent_mod.replace('&rgr;','ρ')
                    one_patent_mod = one_patent_mod.replace('&KHgr;','Χ')
                    one_patent_mod = one_patent_mod.replace('&khgr;','χ')
                    one_patent_mod = one_patent_mod.replace('&Igr;','Ι')
                    one_patent_mod = one_patent_mod.replace('&igr;','ι')
                    one_patent_mod = one_patent_mod.replace('&Tgr;','Τ')
                    one_patent_mod = one_patent_mod.replace('&tgr;','τ')
                    one_patent_mod = one_patent_mod.replace('&Kgr;','Κ')
                    one_patent_mod = one_patent_mod.replace('&kgr;','κ')
                    one_patent_mod = one_patent_mod.replace('&Zgr;','Ζ')
                    one_patent_mod = one_patent_mod.replace('&zgr;','ζ')
                    one_patent_mod = one_patent_mod.replace('&Xgr;','Ξ')
                    one_patent_mod = one_patent_mod.replace('&xgr;','ξ')
                    one_patent_mod = one_patent_mod.replace('&psgr;','Ψ')
                    one_patent_mod = one_patent_mod.replace('&PSgr;','ψ')
                    one_patent_mod = one_patent_mod.replace('&Ogr;','Ο')
                    one_patent_mod = one_patent_mod.replace('&ogr;','ο')
                    
                    one_patent_mod = one_patent_mod.replace('&Asteriskpseud;','')
                    one_patent_mod = one_patent_mod.replace('&Brketclosest;','')
                    one_patent_mod = one_patent_mod.replace('&Brketopenst;','')
                    one_patent_mod = one_patent_mod.replace('&RightDoubleBracketingBar;','')
                    one_patent_mod = one_patent_mod.replace('&LeftDoubleBracketingBar;','')
                    one_patent_mod = one_patent_mod.replace('&Circlesolid;','')
                    one_patent_mod = one_patent_mod.replace('&AutoRightMatch;','')
                    one_patent_mod = one_patent_mod.replace('&AutoLeftMatch;','')
                    one_patent_mod = one_patent_mod.replace('&LeftBracketingBar;','⌈')
                    one_patent_mod = one_patent_mod.replace('&RightBracketingBar;','⌉')
                    one_patent_mod = one_patent_mod.replace('FD&C','')
                    one_patent_mod = one_patent_mod.replace('&Parenopenst;','(')
                    one_patent_mod = one_patent_mod.replace('&Parenclosest;','(')
                    one_patent_mod = one_patent_mod.replace('<<<','<')
                    one_patent_mod = one_patent_mod.replace('>>>','>')
                    one_patent_mod = one_patent_mod.replace('<<','<')
                    one_patent_mod = one_patent_mod.replace('>>','>')
                    one_patent_mod = one_patent_mod.replace('<highlight>','')
                    one_patent_mod = one_patent_mod.replace('</highlight>','')
                    one_patent_mod = one_patent_mod.replace('<bold>','')
                    one_patent_mod = one_patent_mod.replace('</bold>','')
                    one_patent_mod = one_patent_mod.replace('<italic>','')
                    one_patent_mod = one_patent_mod.replace('</italic>','')
                    one_patent_mod = one_patent_mod.replace('<superscript>1</superscript>','')
                    one_patent_mod = one_patent_mod.replace('<superscript>1 </superscript>','')
                    one_patent_mod = one_patent_mod.replace('<superscript> 1</superscript>','')
                    one_patent_mod = one_patent_mod.replace('<subscript>','')
                    one_patent_mod = one_patent_mod.replace('</subscript>','')
                    one_patent_mod = one_patent_mod.replace('<superscript>','')
                    one_patent_mod = one_patent_mod.replace('</superscript>','')
                    one_patent_mod = one_patent_mod.replace('<uline>','')
                    one_patent_mod = one_patent_mod.replace('</uline>','')
                    one_patent_mod = re.sub(r'[A-Z]&',"",one_patent_mod)
                    one_patent_mod = re.sub(r'[0-9]&',"",one_patent_mod)
                    one_patent_mod = re.sub(r'[a-zA-Z]&[a-zA-Z]',"",one_patent_mod)
                    one_patent_mod = one_patent_mod.replace('& ','and ')
                    one_patent_mod = one_patent_mod.replace(' &',' and')
                    one_patent_mod = one_patent_mod.replace('“&”','')
                    one_patent_mod = one_patent_mod.replace("′&",'')
                    one_patent_mod = one_patent_mod.replace(",&",'')
                    one_patent_mod = one_patent_mod.replace("(&)",'')
                    one_patent_mod = one_patent_mod.replace(")&(",'')
                    one_patent_mod = one_patent_mod.replace("&&",'')
                    one_patent_mod = re.sub(r"\s>\s","",one_patent_mod)
                    one_patent_mod = re.sub(r"\s<\s","",one_patent_mod)
                    one_patent_mod = re.sub(r"<[0-9]+","",one_patent_mod)
                    #one_patent_mod = re.sub(r"[0-9]+>[0-9]+","",one_patent_mod)<number>&lsqb;0036&rsqb;</number>
                    one_patent_mod = re.sub(r"<number>\[[0-9]+\.]</number>","",one_patent_mod)
                    one_patent_mod = re.sub(r"<number>[0-9]+\.</number>","",one_patent_mod)
                    one_patent_mod = re.sub(r'<cross-reference target="DRAWINGS">[A-Za-z0-9.\s@]*</cross-reference>',"",one_patent_mod)

                    #one_patent_mod = one_patent.replace('&','')
                    try:
                        tree = ET.fromstring(one_patent_mod)
                    except:
                        print('2dn try, error on:',num_pat)
                        continue
                        
                    #print('Error on:',num_pat)
                    #continue
            

            chem_pat = False
            patent_name = ''
            patent_typ = ''
            patent_date = ''
            for child in tree:
                if child.tag == 'subdoc-bibliographic-information':
                    for subchild in child:
                        if subchild.tag == 'document-id':

                            for sub2child in subchild:
                                #print(sub2child.tag)
                                if sub2child.tag == 'doc-number':
                                    patent_name += 'US' + sub2child.text
                                if sub2child.tag == 'kind-code':
                                    patent_typ += sub2child.text
                                if sub2child.tag == 'document-date':
                                    patent_date += sub2child.text
                if child.tag == 'us-bibliographic-data-grant' or child.tag == 'us-bibliographic-data-application':
                    for subchild in child:
                        if subchild.tag == 'publication-reference':
                            for sub2child in subchild:
                                for sub3child in sub2child:
                                    #print(sub3child.tag)
                                    if sub3child.tag == 'country':
                                        patent_name += sub3child.text
                                    if sub3child.tag == 'doc-number':
                                        patent_name += sub3child.text
                                    if sub3child.tag == 'kind':
                                        patent_typ += sub3child.text
                                    if sub3child.tag == 'date':
                                        patent_date += sub3child.text[:4]    
            for child in tree:
                if  child.tag == 'subdoc-bibliographic-information':

                    for subchild in child:
                        #print(subchild.tag)
                        if subchild.tag == 'technical-information':
                            for sub2child in subchild:
                                #print(sub2child.tag)
                                if sub2child.tag == 'classification-ipc':
                                    for sub3child in sub2child:
                                        if sub3child.tag == 'classification-ipc-primary':
                                            for sub4child in sub3child:
                                                if sub4child.tag == 'ipc':
                                                    if sub4child.text[:3] == 'C07':
                                                        chem_pat = True
                                        if sub3child.tag == 'classification-ipc-secondary':
                                            for sub4child in sub3child:
                                                if sub4child.tag == 'ipc':
                                                    if sub4child.text[:3] == 'C07':
                                                        chem_pat = True
                
                if child.tag == 'us-bibliographic-data-grant' or child.tag == 'us-bibliographic-data-application':
                    for subchild in child:
                        #print(subchild.tag)
                        if subchild.tag == 'classifications-ipcr' or subchild.tag == 'classification-ipc':
                            for sub2child in subchild:
                                class_n = ''
                                if sub2child.tag == 'main-classification':
                                    if sub2child.text[:3] == 'C07':
                                        chem_pat = True
                                if sub2child.tag == 'further-classification':
                                    if sub2child.text[:3] == 'C07':
                                        chem_pat = True
                                #print(sub2child.tag)
                                for sub3child in sub2child:
                                    #print(sub3child.tag)
                                    if sub3child.tag == 'classification-level':

                                        class_n = ''
                                    if sub3child.tag == 'section':
                                        class_n += str(sub3child.text)
                                        #print(sub3child.text)
                                    if sub3child.tag == 'class':
                                        class_n += str(sub3child.text)
                                        #print(sub3child.text)
                                #print(class_n)
                                if class_n == 'C07':
                                    chem_pat = True
            if chem_pat == True:
                count +=1
                for child in tree:
                    if child.tag == 'subdoc-description':
                        record = False 
                        for subchild in child:
                            #print(subchild.tag)
                            if subchild.tag == 'detailed-description':   
                                for sub2child in subchild:
                                    for sub3child in sub2child:
                                        #print(sub3child.text)
                                        if patent_name ==  'US20010020030':
                                            print(num_pat)
                                            pass
                                            #
                                        PAT.append(patent_name)
                                        PAT_T.append(patent_typ)
                                        YEAR.append(patent_date)
                                        Parag.append(sub3child.text)
                    if child.tag == 'description':
                        record = False
                        for subchild in child:
                            if subchild.tag == 'heading':
                                if record == False:
                                    #print(num_pat,subchild.text )
                                    try:
                                        if  any([field in subchild.text.lower() for field in ['intermediate 1','description', 'preparation examples', 'disclosure', 'examples','example 1','experimental', 'preparations']]):
                                            record = True
                                    except:
                                        pass
                            if record == True:
                                #print(subchild.tag)
                                #if patent_name == 'US08357358':    
                                    #print(num_pat)
                                PAT.append(patent_name)
                                PAT_T.append(patent_typ)
                                YEAR.append(patent_date)
                                Parag.append(subchild.text)
                #print(num_pat)
        #print(count)
        try:
            os.makedirs(disk_location + '%s/'%year_now + '/extracted')
        except FileExistsError:
            # directory already exists
            pass
        dicte = {'PatentNumber': PAT, 'PatentYear': YEAR,'PatentType':PAT_T, 'Paragraph': Parag} 
        data  = pd.DataFrame(dicte)
        data.to_csv(disk_location + '%s/extracted/%s_uspto_applic_%d.csv'%(year_now,year_now,file_number),sep='\t',index=False)
# Out:
# F:/US_applications/2023\ipa230105.zip
# F:/US_applications/2023\ipa230112.zip
# F:/US_applications/2023\ipa230119.zip
# F:/US_applications/2023\ipa230126.zip
# F:/US_applications/2023\ipa230202.zip
# F:/US_applications/2023\ipa230209.zip
# F:/US_applications/2023\ipa230216.zip
# F:/US_applications/2023\ipa230223.zip
# F:/US_applications/2023\ipa230302.zip
# F:/US_applications/2023\ipa230309.zip
# F:/US_applications/2023\ipa230316.zip
# F:/US_applications/2023\ipa230323.zip
# F:/US_applications/2023\ipa230330.zip
# error on:  9578
# F:/US_applications/2023\ipa230406.zip
